# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Dataset_TaskC/Test_Results_TaskC2.csv")

# %%
df
# Out:
#                       topic  paper_ID  sentence_ID    info-unit  \
# 0      constituency_parsing         8           16     approach
# 1      constituency_parsing         8           16     approach
# 2      constituency_parsing         8           16     approach
# 3      constituency_parsing         8           16     approach
# 4      constituency_parsing         8           16     approach
# ...                     ...       ...          ...          ...
# 16428    hypernym_discovery         0           63      results
# 16429    hypernym_discovery         0           63      results
# 16430    hypernym_discovery         0           63      results
# 16431    hypernym_discovery         0           63      results
# 16432    hypernym_discovery         0           60  experiments
#
#                                                 sentence  start_index  \
# 0      In this paper , we introduce a parser that com...           19
# 1      In this paper , we introduce a parser that com...           31
# 2      In this paper , we introduce a parser that com...           43
# 3      In this paper , we introduce a parser that com...           55
# 4      In this paper , we introduce a parser that com...           63
# ...                                                  ...          ...
# 16428  On the music industry domain subtask , our sys...          100
# 16429  On the music industry domain subtask , our sys...          108
# 16430  On the music industry domain subtask , our sys...          112
# 16431  On the music industry domain subtask , our sys...          122
# 16432                                            Results            0
#
#        end_index               phrases  labels
# 0             28             introduce       1
# 1             37                parser       0
# 2             51              combines       1
# 3             62               encoder       0
# 4             74           built using       1
# ...          ...                   ...     ...
# 16428        107               ranking       1
# 16429        111                   4th       0
# 16430        117                 among       1
# 16431        142  unsupervised systems       0
# 16432          7               Results       0
#
# [16433 rows x 9 columns]

# %%
df_pred = type_C(df, 1)
df_pred.rename(columns = {'start_index': 'start_pred', 'end_index': 'end_pred', 'phrases': 'pred', 'labels': 'labels_pred', 'num': 'pred_num'}, inplace = True)

# %%
df_obj = type_C(df, 0)
df_obj.rename(columns = {'start_index': 'start_obj', 'end_index': 'end_obj', 'phrases': 'obj', 'labels': 'labels_obj', 'num': 'obj_num'}, inplace = True)

# %%
df_obj
# Out:
#                      topic  paper_ID  sentence_ID    info-unit  \
# 0     constituency_parsing         8           16     approach
# 1     constituency_parsing         8           16     approach
# 2     constituency_parsing         8           16     approach
# 3     constituency_parsing         8           16     approach
# 4     constituency_parsing         8           16     approach
# ...                    ...       ...          ...          ...
# 9936    hypernym_discovery         0           63      results
# 9937    hypernym_discovery         0           63      results
# 9938    hypernym_discovery         0           63      results
# 9939    hypernym_discovery         0           63      results
# 9940    hypernym_discovery         0           60  experiments
#
#                                                sentence  start_obj  end_obj  \
# 0     In this paper , we introduce a parser that com...         31       37
# 1     In this paper , we introduce a parser that com...         55       62
# 2     In this paper , we introduce a parser that com...         88      117
# 3     In this paper , we introduce a parser that com...        125      132
# 4     In this paper , we introduce a parser that com...        148      155
# ...                                                 ...        ...      ...
# 9936  On the music industry domain subtask , our sys...         86       89
# 9937  On the music industry domain subtask , our sys...         93       97
# 9938  On the music industry domain subtask , our sys...        108      111
# 9939  On the music industry domain subtask , our sys...        122      142
# 9940                                            Results          0        7
#
#                                 obj  labels_obj  obj_num
# 0                            parser           0        0
# 1                           encoder           0        1
# 2     self - attentive architecture           0        2
# 3                           decoder           0        3
# 4                           parsing           0        4
# ...                             ...         ...      ...
# 9936                            MAP           0        4
# 9937                           1.88           0        5
# 9938                            4th           0        6
# 9939           unsupervised systems           0        7
# 9940                        Results           0        0
#
# [9941 rows x 10 columns]

# %%
df = pd.merge(df_pred, df_obj, on = ['topic', 'paper_ID', 'sentence_ID', 'info-unit', 'sentence'])

# %%
df
# Out:
#                       topic  paper_ID  sentence_ID info-unit  \
# 0      constituency_parsing         8           16  approach
# 1      constituency_parsing         8           16  approach
# 2      constituency_parsing         8           16  approach
# 3      constituency_parsing         8           16  approach
# 4      constituency_parsing         8           16  approach
# ...                     ...       ...          ...       ...
# 34325    hypernym_discovery         0           63   results
# 34326    hypernym_discovery         0           63   results
# 34327    hypernym_discovery         0           63   results
# 34328    hypernym_discovery         0           63   results
# 34329    hypernym_discovery         0           63   results
#
#                                                 sentence  start_pred  \
# 0      In this paper , we introduce a parser that com...          19
# 1      In this paper , we introduce a parser that com...          19
# 2      In this paper , we introduce a parser that com...          19
# 3      In this paper , we introduce a parser that com...          19
# 4      In this paper , we introduce a parser that com...          19
# ...                                                  ...         ...
# 34325  On the music industry domain subtask , our sys...         112
# 34326  On the music industry domain subtask , our sys...         112
# 34327  On the music industry domain subtask , our sys...         112
# 34328  On the music industry domain subtask , our sys...         112
# 34329  On the music industry domain subtask , our sys...         112
#
#        end_pred       pred  labels_pred  pred_num  start_obj  end_obj  \
# 0            28  introduce            1         0         31       37
# 1            28  introduce            1         0         55       62
# 2            28  introduce            1         0         88      117
# 3            28  introduce            1         0        125      132
# 4            28  introduce            1         0        148      155
# ...         ...        ...          ...       ...        ...      ...
# 34325       117      among            1         6         69       78
# 34326       117      among            1         6         86       89
# 34327       117      among            1         6         93       97
# 34328       117      among            1         6        108      111
# 34329       117      among            1         6        122      142
#
#                                  obj  labels_obj  obj_num
# 0                             parser           0        0
# 1                            encoder           0        1
# 2      self - attentive architecture           0        2
# 3                            decoder           0        3
# 4                            parsing           0        4
# ...                              ...         ...      ...
# 34325                      16 places           0        3
# 34326                            MAP           0        4
# 34327                           1.88           0        5
# 34328                            4th           0        6
# 34329           unsupervised systems           0        7
#
# [34330 rows x 15 columns]

# %%
df.to_csv("Dataset_TaskC/Test_Results_Triplets2_C.csv", index = None)

# %%
df_obj.to_csv("Dataset_TaskC/Test_Results_Triplets2_D.csv", index = None)
